# %% [markdown]
# 문제1
# 두 개의 정수를 입력받아서 다음과 같이 4가지 관계연산자의 결과를 출력하시오
# 이때 입력받은 두 정수를 이용하여 출력하시오
# (JAVA는 1이면 true, 0이면 false를 출력한다.)

# %%
x = input("첫 번째 숫자 4를 입력하시오")
y = input("두 번째 숫자 5를 입력하시오")
x = int(x)
y = int(y)

a = x > y
b = x < y
c = x >= y
d = x <= y

print(a)
print(b)
print(c)
print(d)
# Out:
# 첫 번째 숫자 4를 입력하시오4
# 첫 번째 숫자 5를 입력하시오5
# False
# True
# False
# True

# %% [markdown]
# 문제2
# 3개의 정수를 입력 받아 첫 번째 수가 가장 크면 1 아니면 0을 출력하고 세 개의 수가 모두 같으면 1 아니며 0을 출력하는 프로그램을 작성하시오(JAVA는 1이면 true 0이면 false를 출력한다.)

# %%
x = input("첫 번째 숫자 10을 입력하시오")
y = input("두 번째 숫자 9를 입력하시오")
z = input("세 번째 숫자 9를 입력하시오")
x = int(x)
y = int(y)
z = int(z)

a = x > y and x > z
b = x == y == z

print(a)
print(b)
# Out:
# 첫 번째 숫자 10을 입력하시오9
# 두 번째 숫자 9를 입력하시오10
# 세 번째 숫자 9를 입력하시오10
# False
# False

# %% [markdown]
# 문제3
# 두 개의 정수를 입력받아서 첫 번째수는 후치 증가 연산자를 사용하고 두 번째 수는 전치 감소 연산자를 사용하여 두 수의 곱을 구한 후 각각의 값을 출력하는 프로그램을 작성하시오

# %%
x = input("첫 번째 숫자 10을 입력하시오")
y = input("두 번째 숫자 20을 입력하시오")
x = int(x)
y = int(y)

a = x + 1
b = y - 1
c = a * b
print(a,b,c)
# Out:
# 첫 번째 숫자 10을 입력하시오10
# 두 번째 숫자 20을 입력하시오20
# 11 19 209

# %% [markdown]
# 문제4
# 민수와 기영이의 키와 몸무게를 입력받아 민수가 키도 크고 몸무게도 크면 1 그렇지 않으면 0을 출력하는 프로그램을 작성하시오
# (JAVA는 1이면 true, 0이면 false를 출력한다.)

# %%
a = input("민수의 키150를 입력하시오")
b = input("민수의 몸무게35를 입력하시오")
c = input("기영이의 키145를 입력하시오")
d = input("기영이의 몸무게35를 입력하시오")

if a > c and b > d :
  print ("ture")
else :
    print ("false")
# Out:
# 민수의 키를 입력하시오150
# 민수의 몸무게를 입력하시오36
# 기영이의 키를 입력하시오145
# 기영이의 몸무게를 입력하시오35
# ture
