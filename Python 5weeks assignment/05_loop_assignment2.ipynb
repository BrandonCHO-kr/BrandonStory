# %% [markdown]
# 자연수 n을 입력받고 1부터 홀수를 차례대로 더해나가면서 합이 n이상이면 그 때까지 더해진 홀수의 개수와 그 합을 출력하는 프로그램을 작성하시오

# %%
n = int(input("자연수 n을 입력하시오"))

i = 1
li = []

while sum(li) < n :
  li.append(i)
  i += 2

print(len(li), sum(li))
# Out:
# 자연수 n을 입력하시오100
# 10 100

# %% [markdown]
# 2부터 9까지의 수 중 2개를 입력받아 입력받은 수 사이의 구구단을 출력하는 프로그램을 작성하시오
# 단 반드시 먼저 입력된 수의 구구단부터 아래의 형식에 맞게 출력하여야 한다.
# 구구단 사이의 공백은 3칸이다.

# %%
a = int(input("첫번째 숫자를 입력하시오"))
b = int(input("두번째 숫자를 입력하시오"))

if a <= b :
  for i in range(1 , 10) :
    for j in range(a, b+1, 1 ) :
      print(j, " * ", i, " = " , i*j, end='   ')
    print()
else :
  for i in range(1 , 10) :
    for j in range(a, b-1, -1 ) :
      print(j, " * ", i, " = " , i*j, end='   ')
    print()
# Out:
# 첫번째 숫자를 입력하시오5
# 두번째 숫자를 입력하시오3
# 5  *  1  =  5       4  *  1  =  4       3  *  1  =  3
# 5  *  2  =  10       4  *  2  =  8       3  *  2  =  6
# 5  *  3  =  15       4  *  3  =  12       3  *  3  =  9
# 5  *  4  =  20       4  *  4  =  16       3  *  4  =  12
# 5  *  5  =  25       4  *  5  =  20       3  *  5  =  15
# 5  *  6  =  30       4  *  6  =  24       3  *  6  =  18
# 5  *  7  =  35       4  *  7  =  28       3  *  7  =  21
# 5  *  8  =  40       4  *  8  =  32       3  *  8  =  24
# 5  *  9  =  45       4  *  9  =  36       3  *  9  =  27

# %% [markdown]
# 행과 열의 수를 입력받아 다음과 같이 출력하는 프로그램을 작성하시오

# %%
a = int(input("행을 입력하시오"))
b = int(input("열을 입력하시오"))

x = 1

for i in range(1 , a+1) :
  for j in range(1, b+1) :
    print(i*j, end =' ')
  print()
# Out:
# 행을 입력하시오3
# 열을 입력하시오4
# 1 2 3 4
# 2 4 6 8
# 3 6 9 12

# %% [markdown]
# 자연수 n을 입력받아서 n줄만큼 다음과 같이 출력하는 프로그램을 작성하시오

# %%
 a = int(input("자연수n을 입력하시오"))

for i in range (1, a+1) :
  for j in range (1,i+1) :
    print("*" , end="")
  print()
# Out:
# 자연수n을 입력하시오5
# *
# **
# ***
# ****
# *****

# %% [markdown]
# 자연수 n을 입력받아서 다음과 같이 출력하는 프로그램을 작성하시오

# %%
 a = int(input("자연수n을 입력하시오"))

for i in range ((a*2)-1,0,-2 ) :
  print(' '*(a-i//2-1),end='')

  print('*' * i)
# Out:
# 자연수n을 입력하시오3
# *****
#  ***
#   *

# %% [markdown]
# 1부터 100까지의 정수 중 한 개를 입력받아 100보다 작은 배수들을 차례로 출력하다가 10의 배수가 출력되면 프로그램을 종료하도록 만드시오

# %%
 a = int(input("자연수n을 입력하시오"))

for i in range(a, 101) :
  if i %a == 0 :
    print(i, end=' ')
    if i % 10 == 0 :
      break
# Out:
# 자연수n을 입력하시오7
# 7 14 21 28 35 42 49 56 63 70

# %% [markdown]
# 자연수 n을 입력받아 "출력 예"와 같이 공백으로 구분하여 출력하는 프로그램을 작성하시오 주의! 숫자를 공백으로 구분하되 줄 사이에 빈줄은 없다.

# %%
 n = int(input("자연수n을 입력하시오"))

 for i in range (1, n+1) :
   for j in range(n-i) :
     print(' ',end=' ')
   for j in range(i) :
     print(j+1, end=' ')
   print()
# Out:
# 자연수n을 입력하시오3
#     1
#   1 2
# 1 2 3

# %% [markdown]
# 자연수 n을 입력받아 "출력 예"와 같이 공백으로 구분하여 출력하는 프로그램을 작성하시오 주의! 숫자를 공백으로 구분하되 줄 사이에 빈줄은 없다.

# %%
 n = int(input("자연수n을 입력하시오"))

num = 1

for i in range(n) : 
  for j in range(n) :
    if i <= j :
      print(num, end=' ')
      num += 1
    else :
      print(' ', end= ' ')
  print()
# Out:
# 자연수n을 입력하시오3
# 1 2 3
#   4 5
#     6

# %% [markdown]
# 자연수 n을 입력받아 "출력 예"와 같이 n x n 크기에 공백으로 구분하여 출력되는 프로그램을 작성하시오 10미만의 홀수만 출력하시오
# 주의! 숫자는 공백으로 구분하되 줄  사이에 빈줄은 없다.

# %%
 n = int(input("자연수n을 입력하시오"))

num = 1

for i in range(n) :
  for j in range(n) :
    print(num, end = ' ')
    num += 2
    if num > 10 :
      num = 1
  print()
# Out:
# 자연수n을 입력하시오3
# 1 3 5
# 7 9 1
# 3 5 7
